# %%
print('Cписок доступных марок ЖК-Телевизоров в продаже:\n-LG\n-Samsung\n-SONY\n-KIVI\n-Thomson')
print('Введите марку ЖК-телевизора, которую вы хотели бы приобрести')
tv_mark = input()
print('Список доступных диагоналей экранов:\n-45\n-50\n-55\n-60\n-65')
print('Введите диагональ экрана ЖК-Телевизора')
diag_display_nb = input()
print('Список доступных частот матриц:\n-100 Гц\n-110 Гц\n-120 Гц')
print('Введите выбранную вами частоту матрицы')
matrix_frequancy = input()
print('Выберите мощность звуковой системы:\n-20 Вт\n-25 Вт\n-30 Вт')
print('Введите мощность звуковой системы')
sound_system_power = input()
print('Нужен ли вам встроенный Блютуз:\n-да\n-нет')
print('Введите ваш ответ')
bluetooth = input()
print('Выберите цвет ЖК-Телевизора доступных в нашем магазине:\n-Black\n-White\n-Blue\n-Green')
print('Введите выбранный вами цвет')
tv_colour = input()
print("Спасибо за то, что выбрали наш магазин,\nчерез 5 минут с вами свяжется наш менеджер,\nдля дальнейшего оформления заказа")
print('Ваш заказ\n'
      + '\n-----------------------------'
      + "\nМодель ЖК-Телевизора: " + tv_mark
      + "\nДиагональ экрана: " + diag_display_nb
      + "\nЧастота матрицы: "+ matrix_frequancy
      + "\nМощность звуковой системы: " + sound_system_power
      + "\nБлютуз: " + bluetooth
      + "\nЦвет ЖК-Телевизора: " + tv_colour
      + "\n-----------------------------"
     )


# In[ ]:
# Out:
# Cписок доступных марок ЖК-Телевизоров в продаже:
# -LG
# -Samsung
# -SONY
# -KIVI
# -Thomson
# Введите марку ЖК-телевизора, которую вы хотели бы приобрести
# 1
# Список доступных диагоналей экранов:
# -45
# -50
# -55
# -60
# -65
# Введите диагональ экрана ЖК-Телевизора
# 1
# Список доступных частот матриц:
# -100 Гц
# -110 Гц
# -120 Гц
# Введите выбранную вами частоту матрицы
# 1
# Выберите мощность звуковой системы:
# -20 Вт
# -25 Вт
# -30 Вт
# Введите мощность звуковой системы
# 1
# Нужен ли вам встроенный Блютуз:
# -да
# -нет
# Введите ваш ответ
# 1
# Выберите цвет ЖК-Телевизора доступных в нашем магазине:
# -Black
# -White
# -Blue
# -Green
# Введите выбранный вами цвет
# 1
# Спасибо за то, что выбрали наш магазин,
# через 5 минут с вами свяжется наш менеджер,
# для дальнейшего оформления заказа
# Ваш заказ
#
# -----------------------------
# Модель ЖК-Телевизора: 1
# Диагональ экрана: 1
# Частота матрицы: 1
# Мощность звуковой системы: 1
# Блютуз: 1
# Цвет ЖК-Телевизора: 1
# ...
