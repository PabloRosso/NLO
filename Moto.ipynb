# %%
our_answer = input("Хотите экипировать мотоциклиста(y/n): ")
while True:
    if our_answer.lower() == "y":
        print("Оденьте мотоциклиста в экипировку, находящихся в иерархии!")
        while True:
            our_motorcycle = input("Введите название аммуниции или закончите одевать мотоциклиста('название аммуниции'/e): ")
            if our_motorcycle.lower() != "e":
                if our_motorcycle in price:
                    if our_motorcycle not in cost_of_equipment:
                        cost_of_equipment[our_vegetable] = vegetables_calorie_content[our_vegetable]
                    elif our_vegetable in cost_of_equipment:
                        print("Этот эелемент аммуниции уже присутствует, добавьте другой элемент!")
                else:
                    print("Такого элемента аммуниции нет в иерархии!")
            elif our_motorcycle.lower() == "e":
                if len(cost_of_equipment) > 0:
                    print("Вот так вы экипировали мотоциклиста:")
                    for key in cost_of_equipment:
                        print(key)
                    print("Сортировка аммуниции на основе стоимости:")
                    copy_motorcycle = copy.deepcopy(motorcycle)
                    for value in sorted(motorcycle.values()):
                        for key in copy_motorcycle:
                            if key in cost_of_equipment:
                                if cost_of_equipment[key] == value:
                                    copy_motorcycle.remove(key)
                                    print(key, "-", value)
                    break
                elif len(salad) == 0:
                    print("Ты не акупировал мотоциклиста. Пока!")
                    break
        break
    else:
        print("Пока!")
        break
if len(salad) != 0:
    while True:
        my_answer = input("Хочешь найти аммуницию, соответствующие заданному диапазону стоимости(y/n)?")
        if my_answer.lower() == "y":
            print("Аммуниция из какого диапазона вам интересны")
            my_price_1 = input("Нижний диапазон:")
            my_price_2 = input("Верхнийний диапазон:")
            count = 0
            for value_price in cost_of_equipment.values():
                if int(my_price_1) <= value_price <= int(my_price_2):
                    for key in cost_of_equipment:
                        if cost_of_equipment[key] == value_price:
                            print("Аммуниция", key, ", соответсвующая", cost_of_equipment[key], "стоимости, "
                                  "лежит в вашем диапазоне от", my_price_1, "до", my_price_2)
                            count += 1
            if count == 0:
                print("Аммуниция, соответствующая заданной стоимости "
                      "в вашем диапазоне от", my_price_1, "до",my_price_2,
                      "отсутствует в акипировки!")
        else:
            print("Пока!")
            break
