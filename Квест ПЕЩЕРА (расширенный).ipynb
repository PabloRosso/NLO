# %%
print("""Суть текстового квеста заключается в том, что бы заплутавший путник, проходящий задание в пещере
 - смог найти из нее выход, избегая аномалий и остался в живых!
Путник! Судьба подкидывает Вам испытание на право доказать самому себе, что вы чего то стоите! Вперед и удачи!""")

print('Вы попадаете в пещеру на развилку и перед Вами три дороги:\n-Налево,\n-Прямо,\n-Направо')
print('Ведите путь дороги, который вы выбрали')
road = input()
if (road == 'Налево'):
        print("Вы попадаете в комнату с ядовитыми змеями, которые мгновенно вас жалят и вы умираете!")
        print("КВЕСТ ОКОНЧЕН, ВЫ ПОГИБЛИ!")
    
elif (road == 'Направо'):
    print('Вы нашли сокровище, но забыли о выходе и перед вами упал огромный камень закрывающий вход в пещеру!')
    print(' НО КВЕСТ ЕЩЕ НЕ ОКОНЧЕН, выход отсюда возможен!')
    print('Перед вами прорубь с цифрой 1 и веревочная лестница ведущая наверх с цифрой 2, но она расположена над огнем')
    print('Вы выберете прорубь или огонь?')
let = input()
if let in ('1', '2'):
    print('не знаю такого препятствия, выбери еще раз')
while road == 'Направо':
    if let == 'прорубь':
        print('Ух, это оказалось не просто, но ВЫ СМОГЛИ ВЫБРАТЬСЯ!')
        print('А именно найти Выход из пещеры, который тут не один,но все же! Вы доказали что храбры и опытны! Поздравляем!')
        break
    elif let == 'огонь':
        print('Вы долго думали лестница начала подгорать и вы упали в огонь!')
        print('Вы скончались от шока и смертоносных ожогов! Квест завершен, путник!')
        break    
if (road == 'Прямо'):
    print('Вы упали вниз в яму, но не погибли.')
    print('Внизу оказалось еще два разветвления:\n-КРАСНЫЙ,\n-СИНИЙ')
    print('Введите путь дороги, который вы выбрали')
road_2 = input()
if (road_2 == 'КРАСНЫЙ'):
    print('У входа налево стоит лестница, вы поднялись в комнату уровнем выше, где находятся змеи, которые вас жалят!')
    print('КВЕСТ ЗАВЕРШЕН! ВЫ ОТРАВЛЕНЫ И МЕДЛЕННО УМИРАЕТЕ!')
elif (road_2 =='СИНИЙ'):
    print('У входа направо что-то написано неразборчивым почерком, вы подходите ближе и видите надпись "ВЫХОД"')
    print('БИНГО, ВЫХОД НАЙДЕН, ВЫ СМОГЛИ ВЫБРАТЬСЯ!')
